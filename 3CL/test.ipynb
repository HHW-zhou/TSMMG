# %%
import numpy as np
import pandas as pd

# %%
fname = 'data_split.npz'
data = np.load(fname)

# %%
train_data = data['train'].tolist()
test_data = data['test'].tolist()

# %%
train_data = pd.DataFrame(data=train_data, columns=['name'])
train_data.to_csv('./data/3CL_enzymatic_activity/train.csv', index=False)

# %%
test_data = pd.DataFrame(data=test_data, columns=['name'])
test_data.to_csv('./data/3CL_enzymatic_activity/test.csv', index=False)

# %%
train_data = pd.read_csv('./data/3CL_enzymatic_activity/train.csv')
train_data_list = train_data['name'].tolist()

# %%
c = train_data_list.copy()
c.append('12121212212')
train_data_list
# Out:
# ['6210.png',
#  '4649.png',
#  '73.png',
#  '10097.png',
#  '9453.png',
#  '1713.png',
#  '717.png',
#  '2956.png',
#  '9903.png',
#  '7909.png',
#  '10762.png',
#  '2406.png',
#  '1404.png',
#  '1765.png',
#  '1510.png',
#  '4678.png',
#  '8809.png',
#  '3817.png',
#  '11930.png',
#  '1995.png',
#  '3892.png',
#  '8233.png',
#  '1401.png',
#  '9642.png',
#  '550.png',
#  '9862.png',
#  '2424.png',
#  '6248.png',
#  '7052.png',
#  '1797.png',
#  '6331.png',
#  '6640.png',
#  '4962.png',
#  '2861.png',
#  '7276.png',
#  '7695.png',
#  '7631.png',
#  '5566.png',
#  '2022.png',
#  '679.png',
#  '3605.png',
#  '2314.png',
#  '5491.png',
#  '3746.png',
#  '1451.png',
#  '12122.png',
#  '6976.png',
#  '6732.png',
#  '703.png',
#  '2849.png',
#  '1214.png',
#  '10.png',
#  '2953.png',
#  '11280.png',
#  '2142.png',
#  '11169.png',
#  '5222.png',
#  '10798.png',
#  '10492.png',
#  '11724.png',
#  '2408.png',
#  '7198.png',
#  '255.png',
#  '485.png',
#  '1465.png',
#  '1620.png',
# ...
